# %%
import pickle
from math import sqrt
import numpy as np
outfile = open('../data/Piano-midi.de.pickle','rb')
data = pickle.load(outfile)
print(data["train"][4][19])
outfile.close()
from matplotlib import pyplot
dataset=np.zeros((len(data["train"]), 5000, 120))

for i in range(len(data["train"])): #sample
    for j in range(len(data["train"][i])): #second
        for k in range(len(data["train"][i][j])):
            dataset[i, j, data["train"][i][j][k]]=1; #note

print(dataset.shape)
# Out:
# [57, 67, 72, 76, 79]
# (87, 5000, 120)

# %%
##dataset = pickle.load('../data.Piano-midi.de.pickle')
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
#from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Conv1DTranspose
from tensorflow.keras.layers import Activation
from tensorflow.keras import activations

def define_discriminator(in_shape):
    model = Sequential()
    # normal
    
    model.add(Conv1D(64, 3, padding='same', input_shape=in_shape))
    model.add(LeakyReLU(alpha=0.2))
    # downsample
    model.add(Conv1D(128, 3, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # downsample
    model.add(Conv1D(128, 3, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    # downsample
    model.add(Conv1D(256, 3, strides=2, padding='same'))   
    model.add(LeakyReLU(alpha=0.2))
    # classifier
    model.add(Flatten())
    model.add(Dropout(0.4))
    #model.add(Dense(1, activation='sigmoid'))
    model.add(Activation(activations.sigmoid))
    # compile model
    opt = Adam(lr=0.0004, beta_1=0.5)
    model.compile(loss='mae', optimizer=opt)
    print(model.summary())
    return model

# %%
def save_plot(examples, n_examples):

# %%
def define_generator(latent_dim, output_shape):
    start_height = output_shape[0] // 8
    start_width = output_shape[1] // 8
    
    model = Sequential()

    n_nodes = 256* start_width * start_height
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    #model.add(Reshape((4*start_height, 8*start_width)))
    model.add(Reshape((16*start_height, 16*start_width)))
    
    model.add(Conv1DTranspose(128, 4, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    #model.add(Reshape((8*start_height, 16*start_width)))
    
    model.add(Conv1DTranspose(128, 4, strides=2, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    #model.add(Reshape((16*start_height, 16*start_width)))
    
    model.add(Conv1DTranspose(128, 4, strides=3, padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # output layer
    model.add(Conv1D(5, 3, activation='tanh', padding='same'))
    model.add(Reshape((5000, 120)))
    print(model.summary())
    return model

# %%
def define_gan(g_model, d_model, loss='binary_crossentropy', optimizer=None):
    # make weights in the discriminator not trainable
    d_model.trainable = False
    # connect them
    model = Sequential()
    # add generator
    model.add(g_model)
    # add the discriminator
    model.add(d_model)
    # compile model
    if not optimizer:
        optimizer = Adam(lr=0.0004, beta_1=0.5)
    model.compile(loss=loss, optimizer=optimizer)
    model.add(Flatten())
    print(model.summary())
    return model

# %%
 
import numpy as np
import os
from PIL import Image

# select real samples
def generate_real_samples(dataset, n_samples, multiplier=1.0):
    # choose random instances
    ix = np.random.randint(0, dataset.shape[0], n_samples)
    # select images
    X = dataset[ix]
    # generate class labels, -1 for 'real'
    y = np.ones((n_samples, 1)) * multiplier
    return X, y

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples, multiplier=1.0):
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    # predict outputs
    X = generator.predict(x_input)
    # create class labels with 1.0 for 'fake'
    y = np.ones((n_samples, 1)) * multiplier
    return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = np.random.randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# train the generator and discriminator
def train(genenerator, discriminator, gan_model, dataset, latent_dim, output_path,
          real_samples_multiplier=1.0, fake_samples_multiplier=0.0, discriminator_batches=1,
          n_epochs=100, n_batch=8):
    batch_per_epoch = dataset.shape[0] // n_batch
    half_batch = n_batch // 2
    seed = generate_latent_points(latent_dim, 87)
    n_steps = batch_per_epoch * n_epochs
	
    history = {'discriminator_real_loss': [],
               'discriminator_fake_loss': [],
               'generator_loss': []}
    for step in range(n_steps):
        epoch = step // batch_per_epoch
        disc_loss_real = 0.0
        disc_loss_fake = 0.0
        for disc_batch in range(discriminator_batches):
            X_real, y_real = generate_real_samples(dataset, half_batch,
                                                   multiplier=real_samples_multiplier)
            disc_loss_real += discriminator.train_on_batch(X_real, y_real)
            X_fake, y_fake = generate_fake_samples(genenerator, latent_dim, half_batch,
                                                   multiplier=fake_samples_multiplier)
            disc_loss_fake += discriminator.train_on_batch(X_fake, y_fake)
        disc_loss_real /= discriminator_batches
        disc_loss_fake /= discriminator_batches
        
        X_gan = generate_latent_points(latent_dim, n_batch)
        y_gan = np.ones((n_batch, 1)) * real_samples_multiplier
        g_loss = gan_model.train_on_batch(X_gan, y_gan)
        
        history['discriminator_real_loss'].append(disc_loss_real)
        history['discriminator_fake_loss'].append(disc_loss_fake)
        history['generator_loss'].append(g_loss)
        epoch = step // batch_per_epoch+1
        print('epoch: %d, discriminator_real_loss=%.3f, discriminator_fake_loss=%.3f, generator_loss=%.3f' % (epoch, disc_loss_real, disc_loss_fake, g_loss))

    return history

# %%
dis = define_discriminator((5000, 120))
gen = define_generator(50, (5000, 120))
gan = define_gan(gen, dis)
hist = train(gen, dis, gan, dataset, 50, "xyz")
print(hist)
# Out:
# Model: "sequential_110"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_208 (Conv1D)         (None, 5000, 64)          23104
#
#  leaky_re_lu_313 (LeakyReLU)  (None, 5000, 64)         0
#
#  conv1d_209 (Conv1D)         (None, 2500, 128)         24704
#
#  leaky_re_lu_314 (LeakyReLU)  (None, 2500, 128)        0
#
#  conv1d_210 (Conv1D)         (None, 1250, 128)         49280
#
#  leaky_re_lu_315 (LeakyReLU)  (None, 1250, 128)        0
#
#  conv1d_211 (Conv1D)         (None, 625, 256)          98560
#
#  leaky_re_lu_316 (LeakyReLU)  (None, 625, 256)         0
#
#  flatten_44 (Flatten)        (None, 160000)            0
#
#  dropout_42 (Dropout)        (None, 160000)            0
#
#  activation_26 (Activation)  (None, 160000)            0
#
# =================================================================
# Total params: 195,648
# Trainable params: 195,648
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_111"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_46 (Dense)            (None, 2400000)           122400000
#
#  leaky_re_lu_317 (LeakyReLU)  (None, 2400000)          0
#
#  reshape_60 (Reshape)        (None, 10000, 240)        0
#
#  conv1d_transpose_106 (Conv1  (None, 20000, 128)       123008
#  DTranspose)
#
#  leaky_re_lu_318 (LeakyReLU)  (None, 20000, 128)       0
#
#  conv1d_transpose_107 (Conv1  (None, 40000, 128)       65664
#  DTranspose)
#
#  leaky_re_lu_319 (LeakyReLU)  (None, 40000, 128)       0
#
#  conv1d_transpose_108 (Conv1  (None, 120000, 128)      65664
#  DTranspose)
#
#  leaky_re_lu_320 (LeakyReLU)  (None, 120000, 128)      0
#
#  conv1d_212 (Conv1D)         (None, 120000, 5)         1925
#
#  reshape_61 (Reshape)        (None, 5000, 120)         0
#
# =================================================================
# Total params: 122,656,261
# Trainable params: 122,656,261
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential
discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 4, discriminator_real_loss=0.367, discriminator_fake_loss=0.799, generator_loss=0.278
# epoch: 4, discriminator_real_loss=0.333, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 4, discriminator_real_loss=0.292, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 4, discriminator_real_loss=0.297, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.266, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.261, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.240, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.230, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.225, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.219, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.214, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.211, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 5, discriminator_real_loss=0.209, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 5, discriminator_real_loss=0.207, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.208, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.206, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.206, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.205, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.204, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.204, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.204, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.204, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 6, discriminator_real_loss=0.203, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 6, discriminator_real_loss=0.203, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 7, discriminator_real_loss=0.203, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 7, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.276
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 8, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 9, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 9, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.202, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 10, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 11, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 11, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 12, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 13, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 14, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 15, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 15, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 15, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 16, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 17, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 18, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 19, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 20, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 20, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 21, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 22, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 22, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 23, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 24, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 25, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 26, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 26, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 27, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 27, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.276
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 28, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.278
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 29, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 30, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 31, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 31, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 32, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 33, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 33, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 33, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 33, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 33, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 34, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 35, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 36, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 36, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 37, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 38, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 38, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 39, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.276
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 40, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 41, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 41, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 42, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 43, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 44, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.278
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 45, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 46, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 47, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 47, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.201, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.278
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.199, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 48, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 49, discriminator_real_loss=0.200, discriminator_fake_loss=0.801, generator_loss=0.277
# epoch: 50, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 50, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# epoch: 50, discriminator_real_loss=0.200, discriminator_fake_loss=0.799, generator_loss=0.277
# epoch: 50, discriminator_real_loss=0.200, discriminator_fake_loss=0.800, generator_loss=0.277
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16968/515345653.py in <module>
#       2 gen = define_generator(50, (5000, 120))
#       3 gan = define_gan(gen, dis)
# ----> 4 hist = train(gen, dis, gan, dataset, 50, "xyz")
#       5 print(hist)
#
# ~\AppData\Local\Temp/ipykernel_16968/4011249171.py in train(genenerator, discriminator, gan_model, dataset, latent_dim, output_path, real_samples_multiplier, fake_samples_multiplier, discriminator_batches, n_epochs, n_batch)
#      59         X_gan = generate_latent_points(latent_dim, n_batch)
#      60         y_gan = np.ones((n_batch, 1)) * real_samples_multiplier
# ---> 61         g_loss = gan_model.train_on_batch(X_gan, y_gan)
#      62
#      63         history['discriminator_real_loss'].append(disc_loss_real)
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1898                                                     class_weight)
#    1899       self.train_function = self.make_train_function()
# -> 1900       logs = self.train_function(iterator)
#    1901
#    1902     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\Bootcamp2021\bootcamp_env\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Kernel interrupted because it propbably won't give better results.
#
# Dataset problems (!):
#
#
#
# -only 87 samples in dataset, model probably overfit
#
# -some samples are 10s long, some are 5000s long (I will try to chop the longer ones and give it to shorter ones)
#
# -Very slow training (generating matrix 5000x120)
#
# To do:
#
#
#
# -balance the length of samples
#
# -convert matrices to images so we can actually see the output
